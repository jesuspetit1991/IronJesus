# %%
#IMPORTANT

import pandas as pd
import numpy as np

# %%
#READING FILE1 and drop NaN

df1 = pd.read_csv("files_for_lab/csv_files/file1.csv")
df1 = df1.dropna()
display(df1)
# Out:
#      Customer       State Gender             Education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# ...

# %%
#DF1 SHAPE

df1.shape
# Out:
# (952, 11)

# %%
df1.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints',
#        'Total_Claim_Amount', 'Policy_Type', 'Vehicle_Class'],
#       dtype='object')

# %%
#Standardize header names.

df1.columns = ['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount']
df1
# Out:
#      Customer       State Gender             Education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# ...

# %%
#Rearrange the columns in the dataframe as needed

df1 = df1[['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount']]
df1.head()
# Out:
#   Customer       State Gender             Education Customer_Lifetime_Value  \
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
#
#     Income  Monthly_Premium_Auto Number_of_Open_Complaints  Policy_Type  \
# 1      0.0                  94.0                    1/0/00  1131.464935
# 2  48767.0                 108.0                    1/0/00   566.472247
# 3      0.0                 106.0                    1/0/00   529.881344
# 4  36357.0                  68.0                    1/0/00    17.269323
# 5  62902.0                  69.0                    1/0/00   159.383042
#
#     Vehicle_Class Total_Claim_Amount
# 1   Personal Auto      Four-Door Car
# ...

# %%
#READING FILE2 and drop NaN

df2 = pd.read_csv("files_for_lab/csv_files/file2.csv")
df2 = df2.dropna()
display(df2)
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
#DF2 SHAPE

df2.shape
# Out:
# (988, 11)

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
#Standardize header names.

df2.columns = ['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Total_Claim_Amount', 'Policy_Type', 'Vehicle_Class']
df2
# Out:
#     Customer       State Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_of_Open_Complaints  Total_Claim_Amount  \
# ...

# %%
#Rearrange the columns in the dataframe as needed

df2 = df2[['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount']]
df2.head()
# Out:
#   Customer       State Gender Education Customer_Lifetime_Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly_Premium_Auto Number_of_Open_Complaints     Policy_Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Vehicle_Class  Total_Claim_Amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
#READING FILE3 and drop NaN

df3 = pd.read_csv("files_for_lab/csv_files/file3.csv")
df3 = df3.dropna()
display(df3)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#df3 SHAPE

df3.shape
# Out:
# (7070, 11)

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
# DF3 Standardize header names.

df3.columns = ['Customer', 'State', 'Customer_Lifetime_Value', 'Education', 'Gender','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Policy_Type', 'Total_Claim_Amount', 'Vehicle_Class']
df3
# Out:
#      Customer       State  Customer_Lifetime_Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly_Premium_Auto  Number_of_Open_Complaints  \
# ...

# %%
#Rearrange the columns in the dataframe as needed

df3 = df3[['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value','Income', 'Monthly_Premium_Auto', 'Number_of_Open_Complaints','Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount']]
df3.head()
# Out:
#   Customer       State Gender             Education  Customer_Lifetime_Value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    Income  Monthly_Premium_Auto  Number_of_Open_Complaints    Policy_Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Vehicle_Class  Total_Claim_Amount
# ...

# %%
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 952 entries, 1 to 1070
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   952 non-null    object
#  1   State                      952 non-null    object
#  2   Gender                     952 non-null    object
#  3   Education                  952 non-null    object
#  4   Customer_Lifetime_Value    952 non-null    object
#  5   Income                     952 non-null    float64
#  6   Monthly_Premium_Auto       952 non-null    float64
#  7   Number_of_Open_Complaints  952 non-null    object
#  8   Policy_Type                952 non-null    float64
#  9   Vehicle_Class              952 non-null    object
#  10  Total_Claim_Amount         952 non-null    object
# dtypes: float64(3), object(8)
# memory usage: 89.2+ KB
#      Customer       State Gender             Education  \
# ...

# %%
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 988 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   988 non-null    object
#  1   State                      988 non-null    object
#  2   Gender                     988 non-null    object
#  3   Education                  988 non-null    object
#  4   Customer_Lifetime_Value    988 non-null    object
#  5   Income                     988 non-null    int64
#  6   Monthly_Premium_Auto       988 non-null    int64
#  7   Number_of_Open_Complaints  988 non-null    object
#  8   Policy_Type                988 non-null    object
#  9   Vehicle_Class              988 non-null    object
#  10  Total_Claim_Amount         988 non-null    float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 92.6+ KB
#     Customer       State Gender Education Customer_Lifetime_Value  Income  \
# ...

# %%
df3.info()
df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Gender                     7070 non-null   object
#  3   Education                  7070 non-null   object
#  4   Customer_Lifetime_Value    7070 non-null   float64
#  5   Income                     7070 non-null   int64
#  6   Monthly_Premium_Auto       7070 non-null   int64
#  7   Number_of_Open_Complaints  7070 non-null   int64
#  8   Policy_Type                7070 non-null   object
#  9   Vehicle_Class              7070 non-null   object
#  10  Total_Claim_Amount         7070 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB
#      Customer       State Gender             Education  \
# ...

# %%
#Concatenate the three dataframes

df4 = pd.concat([df1, df2, df3], ignore_index=True)

df4.head(20)
# Out:
#    Customer       State Gender             Education Customer_Lifetime_Value  \
# 0   QZ44356     Arizona      F              Bachelor              697953.59%
# 1   AI49188      Nevada      F              Bachelor             1288743.17%
# 2   WW63253  California      M              Bachelor              764586.18%
# 3   GA49547  Washington      M  High School or Below              536307.65%
# 4   OC83172      Oregon      F              Bachelor              825629.78%
# 5   XZ87318      Oregon      F               College              538089.86%
# 6   CF85061     Arizona      M                Master              721610.03%
# 7   DY87989      Oregon      M              Bachelor             2412750.40%
# 8   BQ94931      Oregon      F               College              738817.81%
# 9   SX51350  California      M               College              473899.20%
# 10  QK46697  Washington      M             Bachelors              617710.93%
# ...

# %%
#Which columns are numerical? Income and Monthly_Premium_Auto

#Which columns are categorical? Customer, State, Gender, Education, Customer_Lifetime_Value, Number_of_Open_Complaints, Policy_Type, Vehicle_Class, Total_Claim_Amount

df4.dtypes
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9010 entries, 0 to 9009
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   9010 non-null   object
#  1   State                      9010 non-null   object
#  2   Gender                     9010 non-null   object
#  3   Education                  9010 non-null   object
#  4   Customer_Lifetime_Value    9010 non-null   object
#  5   Income                     9010 non-null   float64
#  6   Monthly_Premium_Auto       9010 non-null   float64
#  7   Number_of_Open_Complaints  9010 non-null   object
#  8   Policy_Type                9010 non-null   object
#  9   Vehicle_Class              9010 non-null   object
#  10  Total_Claim_Amount         9010 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 774.4+ KB

# %%
# Delete the column education and the number of open complaints from the dataframe.
df5 = df4.drop("Education", axis=1)
df5.drop("Number_of_Open_Complaints", axis=1, inplace=True)
df5
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     QZ44356     Arizona      F              697953.59%      0.0
# 1     AI49188      Nevada      F             1288743.17%  48767.0
# 2     WW63253  California      M              764586.18%      0.0
# 3     GA49547  Washington      M              536307.65%  36357.0
# 4     OC83172      Oregon      F              825629.78%  62902.0
# ...       ...         ...    ...                     ...      ...
# 9005  LA72316  California      M             23405.98798  71941.0
# 9006  PK87824  California      F             3096.511217  21604.0
# 9007  TD14365  California      M             8163.890428      0.0
# 9008  UP19263  California      M             7524.442436  21941.0
# 9009  Y167826  California      M             2611.836866      0.0
#
#       Monthly_Premium_Auto     Policy_Type   Vehicle_Class Total_Claim_Amount
# 0                     94.0     1131.464935   Personal Auto      Four-Door Car
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

df5.Customer_Lifetime_Value=df5.Customer_Lifetime_Value.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb Celda 23 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# ----> <a href='vscode-notebook-cell:/Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> df5.Customer_Lifetime_Value=df5.Customer_Lifetime_Value.astype(int)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
# Check for duplicate rows in the data and remove if any.
df5=df5.drop_duplicates()
df5
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     QZ44356     Arizona      F              697953.59%      0.0
# 1     AI49188      Nevada      F             1288743.17%  48767.0
# 2     WW63253  California      M              764586.18%      0.0
# 3     GA49547  Washington      M              536307.65%  36357.0
# 4     OC83172      Oregon      F              825629.78%  62902.0
# ...       ...         ...    ...                     ...      ...
# 9005  LA72316  California      M             23405.98798  71941.0
# 9006  PK87824  California      F             3096.511217  21604.0
# 9007  TD14365  California      M             8163.890428      0.0
# 9008  UP19263  California      M             7524.442436  21941.0
# 9009  Y167826  California      M             2611.836866      0.0
#
#       Monthly_Premium_Auto     Policy_Type   Vehicle_Class Total_Claim_Amount
# 0                     94.0     1131.464935   Personal Auto      Four-Door Car
# ...

# %%
# Filter out the data for customers who have an income of 0 or less.

No_income = df5["Income" < 100000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb Celda 25 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # Filter out the data for customers who have an income of 0 or less.
# ----> <a href='vscode-notebook-cell:/Users/jesuspetit/ironhack_workspace/activities/lab-customer-analysis-round-1/Lab_1.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> No_income = df5["Income" < 100000]
#
# TypeError: '<' not supported between instances of 'str' and 'int'
